# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import os
from tqdm import tqdm_notebook as tqdm
# %matplotlib notebook

# %% [markdown]
# # Load the excel file, and get the sheets

# %%
survey_data_filename = "../dataset/qasurvey.xlsx"

# %%
df = pd.read_excel(survey_data_filename, sheet_name='Data', skiprows=2)

# %%
df
# Out:
#       id  q101  q101a                      q101b  q102  q103  q104  q106  \
# 0    1.0   1.0    1.0              Bode, khapala   7.0   9.0   NaN   1.0
# 1    2.0   3.0    8.0                     Sehari  13.0   NaN  14.0   NaN
# 2    3.0   1.0   16.0                 Lokanthali   6.0   8.0   NaN   1.0
# 3    4.0   1.0    5.0  Nagadesh, Madhyapur thimi   6.0   5.0   NaN   1.0
# 4    5.0   1.0    7.0            Madhyapur thimi   6.0   6.0   NaN   1.0
# ..   ...   ...    ...                        ...   ...   ...   ...   ...
# 479  NaN   NaN    NaN                        NaN   NaN   NaN   NaN   NaN
# 480  NaN   NaN    NaN                        NaN   NaN   NaN   NaN   NaN
# 481  NaN   NaN    NaN                        NaN   NaN   NaN   NaN   NaN
# 482  NaN   NaN    NaN                        NaN   NaN   NaN   NaN   NaN
# 483  NaN   NaN    NaN                        NaN   NaN   NaN   NaN   NaN
#
#      q107  q201  ...  q441a  q441a1  q441a2  q441a3  q441a4  q441a5  q441a6  \
# 0     2.0   2.0  ...    NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN   NaN  ...    NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     4.0   2.0  ...    NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     2.0   1.0  ...    NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     2.0   2.0  ...    NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ..    ...   ...  ...    ...     ...     ...     ...     ...     ...     ...
# 479   NaN   NaN  ...    NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 480   NaN   NaN  ...    NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 481   NaN   NaN  ...    NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 482   NaN   NaN  ...    NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 483   NaN   NaN  ...    NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#      q441a7  q441a8  q441a9
# 0       NaN     NaN     NaN
# 1       NaN     NaN     NaN
# 2       NaN     NaN     NaN
# 3       NaN     NaN     NaN
# 4       NaN     NaN     NaN
# ..      ...     ...     ...
# 479     NaN     NaN     NaN
# 480     NaN     NaN     NaN
# 481     NaN     NaN     NaN
# 482     NaN     NaN     NaN
# 483     NaN     NaN     NaN
#
# [484 rows x 1440 columns]

# %% [markdown]
# # Helper functions

# %%
def expand_categories(values):
    result = []
    s = values.value_counts()
    t = float(len(values))
    for v in s.index:
        result.append("{}:{}%".format(v,round(100*(s[v]/t),2)))
    return "[{}]".format(",".join(result))
        
def analyze(filename):
    print()
    print("Analyzing: {}".format(filename))
    df = pd.read_csv(filename,encoding=ENCODING)
    cols = df.columns.values
    total = float(len(df))

    print("{} rows".format(int(total)))
    for col in cols:
        uniques = df[col].unique()
        unique_count = len(uniques)
        if unique_count>2000:
            print("** {}:{} ({}%)".format(col,unique_count,int(((unique_count)/total)*100)))
        else:
            print("** {}:{}".format(col,expand_categories(df[col])))
            expand_categories(df[col])

def analyze_df(dataframe):
    df = dataframe
    cols = df.columns.values
    total = float(len(df))
    print("{} rows".format(int(total)))
    for col in cols:
        uniques = df[col].unique()
        unique_count = len(uniques)
        if pd.isnull(df[col]).all():
            df = df.drop(col,axis=1)
        else:
            if unique_count > 2000:
                print("** {}:{} ({}%)".format(col,unique_count,int(((unique_count)/total)*100)))
            else:
                print("** {}:{}".format(col,expand_categories(df[col])))
                expand_categories(df[col])
    return df

# %%
grouped_df = df.groupby(["q101"])
