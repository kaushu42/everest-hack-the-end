# %%
import json
import os

import pandas as pd
import numpy as np

# %%
os.getcwd()
# Out:
# '/home/keshavchaurasia/Desktop/codes/everest-hack-the-end/notebooks'

# %%
xls = pd.ExcelFile('../dataset/qasurvey.xlsx')

# %%
xls.sheet_names
# Out:
# ['Urban Health Baseline- for GIZ', 'Data', 'survey', 'choices']

# %%
df_data = pd.read_excel(xls, sheet_name='Data', skiprows=2)
df_data = df_d    dex('id', inplace=True)
df_data.head()
# Out:
#     id  q101  q101a                      q101b  q102  q103  q104  q106  q107  \
# 0  1.0   1.0    1.0              Bode, khapala   7.0   9.0   NaN   1.0   2.0
# 1  2.0   3.0    8.0                     Sehari  13.0   NaN  14.0   NaN   NaN
# 2  3.0   1.0   16.0                 Lokanthali   6.0   8.0   NaN   1.0   4.0
# 3  4.0   1.0    5.0  Nagadesh, Madhyapur thimi   6.0   5.0   NaN   1.0   2.0
# 4  5.0   1.0    7.0            Madhyapur thimi   6.0   6.0   NaN   1.0   2.0
#
#    q201  ...  q441a  q441a1  q441a2  q441a3  q441a4  q441a5  q441a6  q441a7  \
# 0   2.0  ...    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1   NaN  ...    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2   2.0  ...    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3   1.0  ...    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4   2.0  ...    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    q441a8  q441a9
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN
#
# [5 rows x 1440 columns]

# %%
df_choices = pd.read_excel(xls, sheet_name='choices', skiprows=0)
# data = data.loc[:407]
# data['id'] = data['id'].astype(int)
# data.set_index('id', inplace=True)
df_choices = df_choices[pd.notnull(df_choices['list name'])]
df_choices['name'] = df_choices['name'].astype(int)
df_choices = df_choices[['list name', 'name', 'label::english']]
# Out:
#   list name  name  display_name label::english label::nepali  \
# 0       NaN   NaN           NaN            NaN           NaN
# 1  district   1.0           NaN      Bhaktapur       भक्तपुर
# 2  district   2.0           NaN          Banke         बाँके
# 3  district   3.0           NaN        Kailali        कैलाली
# 4       NaN   NaN           NaN            NaN           NaN
#
#    media::image::english  media::video::english  media::audio::english  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    media::image::nepali  media::video::nepali  media::audio::nepali  dist1  \
# 0                   NaN                   NaN                   NaN    NaN
# 1                   NaN                   NaN                   NaN    NaN
# 2                   NaN                   NaN                   NaN    NaN
# 3                   NaN                   NaN                   NaN    NaN
# 4                   NaN                   NaN                   NaN    NaN
#
#    q101  q101_b  q101_c  q101_a  q102  q102a
# 0   NaN     NaN     NaN     NaN   NaN    NaN
# 1   NaN     NaN     NaN     NaN   NaN    NaN
# 2   NaN     NaN     NaN     NaN   NaN    NaN
# 3   NaN     NaN     NaN     NaN   NaN    NaN
# 4   NaN     NaN     NaN     NaN   NaN    NaN

# %%
df_choices
# Out:
#          list name  name                  label::english
# 1         district     1                       Bhaktapur
# 2         district     2                           Banke
# 3         district     3                         Kailali
# 5             name     1                             NaN
# 6             name     2                             NaN
# ...            ...   ...                             ...
# 2861         q1303     3                              No
# 2863  inter_status     1             Interview completed
# 2864  inter_status     2        Refuse to give interview
# 2865  inter_status     3  Interview incomplete (specify)
# 2866  inter_status     4    Interview complete (Remarks)
#
# [2187 rows x 3 columns]

# %%
group_names = df_choices['list name'].value_counts().index

# %%
group_names
# Out:
# Index(['q103', 'name', 'q102', 'q301a10b', 'q301b6b', 'q301b0b', 'q301a8b',
#        'q301b16b', 'q301b9b', 'q301b3b',
#        ...
#        'q1007b', 'q1050b', 'q301b13', 'q401t', 'q1107c', 'q301b22', 'q430a',
#        'q401y', 'q301b19', 'q301c16'],
#       dtype='object', length=680)

# %%
grouped_choices = df_choices.groupby('list name')

# %%
mappings = {} 
for group_name in group_names:
    mappings[group_name] = grouped_choices.get_group(group_name).drop(['list name'], axis=1)

# %%
t = mappings['q301a1']

# %%
dict(t.values)
# Out:
# {1: 'Yes', 2: 'No'}

# %%
for i in mappings:
    try:
        t = mappings[i]
        df_data[i] = df_data[i].map(dict(t.values))
    except:
        pass

# %%
df_data.to_csv("mapped_data.csv")
