# %%
corr = [['Ward No', 1, 'NTG+++'],
 ['Ward No', 2, 'NGT+++'],
 ['Ward No', 4, 'TNG---'],
 ['Ward No', 5, 'NTG+++'],
 ['Ward No', 6, 'NGT+++'],
 ['Ward No', 7, 'NTG+++'],
 ['Ward No', 8, 'TNG---'],
 ['Ward No', 9, 'TNG---'],
 ['Ward No', 12, 'TNG---'],
 ['Ward No', 13, 'NGT+++'],
 ['Ward No', 14, 'NTG+++'],
 ['Ward No', 15, 'TNG+++'],
 ['Ward No', 16, 'TNG+++'],
 ['Ward No', 17, 'NTG+++'],
 ['He/she is health facility in-charge or not?', 'Yes', 'NTG+++'],
 ['He/she is health facility in-charge or not?', 'No', 'NTG+++'],
 ['Window needs repair?', 'No', 'NTG+++'],
 ['Number of rooms available in the health facilities? Number', 2.0, 'NTG+++'],
 ['Number of rooms available in the health facilities? Number', 5.0, 'TNG+++'],
 ['Number of rooms available in the health facilities? Number', 8.0, 'NTG+++'],
 ['Do the health facility manage the accommodation facility for staff when needed?',
  'No',
  'NTG+++'],
 ['Do the health facility manage the accommodation facility for staff when needed?',
  'Yes',
  'NGT+++'],
 ['Is separate/ private space for ANC/PNC checkup available? अलग ANC र PNC जाँचको लागि र निजी स्थान उपलब्ध छरु',
  'Yes',
  'NTG+++'],
 ['OPD service avaliable?', 'Yes', 'NTG+++'],
 ['Immunization Service Avaliable', 'Yes', 'NTG+++'],
 ['Immunization Service Avaliable', 'No', 'NGT+++'],
 ['Postnatal service Service Avaliable', 'Yes', 'NTG+++'],
 ['q301a11 Service Avaliable', 'Yes', 'NTG+++'],
 ['Oral pills for family planning Service Avaliable', 'Yes', 'NTG+++'],
 ['IUCD Service Avaliable', 'No', 'NTG+++'],
 ['IUCD Service Avaliable', 'Yes', 'NGT+++'],
 ['Female sterilization Service Avaliable', 'No', 'NTG+++'],
 ['Female sterilization Service Avaliable', 'Yes', 'NTG+++'],
 ['q301b1 Service Avaliable', 'Yes', 'NTG+++'],
 ['Acute exacerbation of COPD and asthma emergency management Service Avaliable',
  'Yes',
  'NTG+++'],
 ['Acute exacerbation of COPD and asthma emergency management Service Avaliable',
  'No',
  'NTG+++'],
 ['PMTCT Service Avaliable', 'Yes', 'NTG+++'],
 ['PMTCT Service Avaliable', 'No', 'NTG+++'],
 ['NCD Service Avaliable', 'Yes', 'NTG+++'],
 ['NCD Service Avaliable', 'No', 'NGT+++'],
 ['Micro-nutrients supplementation (iron, folic acid, zinc, vitaminA, iodine) Service Avaliable',
  'Yes',
  'NTG+++'],
 ['Micro-nutrients supplementation (iron, folic acid, zinc, vitaminA, iodine) Service Avaliable',
  'No',
  'NTG+++'],
 ['Post abortion care (CAC/PAC) Service Avaliable', 'No', 'NTG+++'],
 ['Sanctioned Post.4', 1.0, 'NTG+++'],
 ['Sanctioned Post.4', 2.0, 'NTG+++'],
 ['Filled Post.4', 0.0, 'NGT+++'],
 ['Filled Post.4', 2.0, 'NTG+++'],
 ['Available on the day of visit.4', 1.0, 'NTG+++'],
 ['Available on the day of visit.4', 2.0, 'NGT+++'],
 ['Deputed staff (In).4', 0.0, 'NTG+++'],
 ['Deputed staff (Out).4', 0.0, 'NTG+++'],
 ['HFOMC/ HDC.4', 0.0, 'NTG+++'],
 ['MoHP.4', 0.0, 'NTG+++'],
 ['MoHP.4', 1.0, 'NGT+++'],
 ['MUNICIPALITY.4', 0.0, 'NTG+++'],
 ['NPC.4', 0.0, 'NTG+++'],
 ['Sanctioned Post.5', 1.0, 'NTG+++'],
 ['Filled Post.5', 1.0, 'NTG+++'],
 ['Available on the day of visit.5', 1.0, 'NTG+++'],
 ['Deputed staff (In).5', 0.0, 'NTG+++'],
 ['Deputed staff (Out).5', 0.0, 'NTG+++'],
 ['HFOMC/ HDC.5', 0.0, 'NTG+++']]

# %%
''[
    'Immunization Service Avaliable',
    'Postnatal service Service Avaliable',    
]

'Percentage of institutional deliveries': [
        'Immunization Service Avaliable',
        'IUCD Service Avaliable',
        'NCD Service Avaliable'
]
